# %%
from requests import get

from requests.exceptions import RequestException

from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd

import re
import time
from my_secrets import GOOGLE_MAPS_API_KEY
import json

REQUEST_ARGS = dict(
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'},
)


class NoResponseError(Exception):
    pass

class NotFoundError(Exception):
    pass

def simple_get(url,args = REQUEST_ARGS):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url,**args)) as resp: #stream=True
            if is_good_response(resp):
                return resp
            elif resp.status_code == 404:
                print('404')
                raise NotFoundError()
            else:
                print('no response')
                return NoResponseError(f'HTTP status code: {resp.status_code}')

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)



def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

SITE = "http://www.district-trivia.com"

WHERE = "/where/is-trivia"

DAYS = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

DAY_DICT = dict(
    Mon = 'Monday',Tue = 'Tuesday',
    Wed = 'Wednesday',Thu = 'Thursday',Fri='Friday',
    Sat='Saturday',Sun='Sunday'
)

# %%
response = simple_get(SITE+WHERE)
raw_html = response.content
print(len(raw_html))

html = BeautifulSoup(raw_html, 'html.parser')
dcvenues = html.find_all("a",href=re.compile("^/venues/dc"))
mdvenues = html.find_all("a",href=re.compile("^/venues/maryland"))
vavenues = html.find_all("a",href=re.compile("^/venues/virginia"))
vdict = dict(DC=dcvenues,MD=mdvenues,VA=vavenues)
venue_list = []

for st,venues in vdict.items():
    for tag in venues:
        if tag.string!=None:

            response = simple_get(SITE+tag.get('href'))
            raw_html = response.content
            #print(len(raw_html))
            html = BeautifulSoup(raw_html, 'html.parser')

            time_tag = html.find("h5")
            #print(timeTag.text)
            vday,vtime = time_tag.text.split(" at ")
            table = html.find_all('div',attrs={"class":"four columns"})
            # print(table)
            url = table[1].find('a').get('href')
            # fb = table[1].find()
            # addressTag = table[-1].find('p')
            
            # for br in addressTag.find_all("br"):
            #     br.replace_with("\n")

            # venueAddresses[i] = addressTag.text
            #print(addressTag.text)
            time.sleep(1)

            venue_list.append(
                dict(
                    name = tag.string,
                    href = tag.get('href'),
                    url = url,
                    state = st,
                    day = vday,
                    time = vtime,
                )
            )

# venues = dcvenues + mdvenues + vavenues

# venues = [tag for tag in venues if tag.string!=None]
# n = len(venues)
# venueUrls = [tag.get('href') for tag in venues]

# venueNames = [tag.string for tag in venues]
# #print(venues[1].get('href'))
# #print(venues[1].text)
# print(len(venueNames))
# print(venues[:5])
# print(venueNames[:5])
# print(venueUrls[:5])

# venueTimes = [None]*n
# venueDays = [None]*n
# venueAddresses = [None]*n
# i=0
# for tag in venues:  
#     response = simple_get(SITE+tag.get('href'))
#     raw_html = response.content
#     #print(len(raw_html))
#     html = BeautifulSoup(raw_html, 'html.parser')

#     timeTag = html.find("h5")
#     #print(timeTag.text)
#     venueDays[i],venueTimes[i] = timeTag.text.split(" at ")
#     table = html.find_all('div',attrs={"class":"four columns"})
#     addressTag = table[-1].find('p')
    
#     for br in addressTag.find_all("br"):
#         br.replace_with("\n")

#     venueAddresses[i] = addressTag.text
#     #print(addressTag.text)
#     i += 1
#     time.sleep(1)
#     print(i)
#     #for x in table:
#     #    print(x.find('p'))
#     #    addressTag = x.find('p')
#     #addressTags = html.descendants.find("p",string=re.compile("Washington, DC 2"))
#     #print(addressTag.text)
#     #print(addressTag.text)
#     #print(timeTag.text)

# venueData = pd.DataFrame(data={'Venue':venueNames,
#     'Address':venueAddresses,'Day':venueDays,'Time':venueTimes, 'Host':'District Trivia'})
# Out:
# 68600

# %%
len(venue_list)
# Out:
# 31

# %%
df_dist = pd.DataFrame.from_records(venue_list)

# %%
df_dist = df_dist[['name','url','state','day','time']]
#df_dist['day'] = df_dist['day']#.str.lower()

# %%
df_dist
# Out:
#                            name  \
# 0      Franklin Hall (Tuesdays)
# 1            Stadium Sports Bar
# 2           Capitol Cider House
# 3            The Eleanor (NoMa)
# 4               Across the Pond
# 5                  Crown & Crow
# 6               Astro Beer Hall
# 7                     Hook Hall
# 8                       Crimson
# 9             The Fainting Goat
# 10          Bonchon (Navy Yard)
# 11                  Penn Social
# 12                        TAP99
# 13                   Free State
# 14                The Big Stick
# 15    Irish Channel (Chinatown)
# 16      Franklin Hall (Mondays)
# 17                 Lost & Found
# 18                Roofers Union
# 19           The Board and Brew
# 20     Looney's Pub (Wednesday)
# 21           Caddies on Cordell
# 22  The Eleanor (Silver Spring)
# 23     True Respite Brewing Co.
# 24    World of Beer (RVILL WED)
# 25                 Highline RxR
# 26                 Auld Shebeen
# 27          Bar Bao (Thursdays)
# 28              Clare and Don's
# 29             Courthaus Social
# 30                  Blue Iguana
#
#                                                   url state        day    time
# 0                     https://www.franklinhalldc.com/    DC    Tuesday  7:00PM
# 1                    https://www.stadiumsportsdc.com/    DC  Wednesday  7:00PM
# 2                      https://capitolciderhouse.com/    DC   Thursday  7:00PM
# 3                          https://www.eleanordc.com/    DC     Sunday  7:30PM
# 4                    https://www.acrosstheponddc.com/    DC  Wednesday  7:30PM
# 5                     http://www.thecrownandcrow.com/    DC  Wednesday  7:30PM
# 6                       https://www.astrobeerhall.com    DC  Wednesday  7:00PM
# 7                           https://www.hookhall.com/    DC   Thursday  7:00PM
# 8                             https://crimson-dc.com/    DC    Tuesday  7:00PM
# 9                     https://www.faintinggoatdc.com/    DC  Wednesday  7:00PM
# 10  https://bonchon.com/korean-fried-chicken-navy-...    DC    Tuesday  7:00PM
# 11                           http://pennsocialdc.com/    DC    Tuesday  7:00PM
# 12                   https://www.facebook.com/tap99dc    DC     Monday  7:00PM
# 13                      https://www.freestatebar.com/    DC     Sunday  7:00PM
# 14                            http://thebigstick.com/    DC  Wednesday  8:00PM
# 15                     http://www.irishchanneldc.com/    DC  Wednesday  7:00PM
# 16                    https://www.franklinhalldc.com/    DC     Monday  7:00PM
# 17                     http://www.lostandfounddc.com/    DC     Monday  8:00PM
# 18                    http://roofersuniondc.com/#info    DC   Thursday  7:30PM
# 19                    http://www.theboardandbrew.com/    MD   Thursday  7:30PM
# 20      http://www.looneyspubmd.com/college_park.html    MD  Wednesday  7:00PM
# 21                   http://www.caddiesoncordell.com/    MD    Tuesday  7:30PM
# 22                         https://www.eleanormd.com/    MD     Sunday  7:30PM
# 23                           https://truerespite.com/    MD   Thursday  7:00PM
# 24        https://worldofbeer.com/Locations/Rockville    MD  Wednesday  7:00PM
# 25                            http://highlinerxr.com/    VA     Monday  7:00PM
# 26                      https://theauldshebeenva.com/    VA    Tuesday  7:30PM
# 27                 https://www.facebook.com/barbaova/    VA   Thursday  7:00PM
# 28                       http://www.clareanddons.com/    VA   Thursday  7:00PM
# 29  mailto:courthaussocial@gmail.com?Subject=Distr...    VA  Wednesday  7:00PM
# 30                      http://blueiguanafairfax.com/    VA   Thursday  7:00PM

# %%
SITE = 'https://triviakings.com/locations/'

raw_html = simple_get(SITE).content
print(len(raw_html))

html = BeautifulSoup(raw_html, 'html.parser')
venueTable = html.find('table')

dfs = pd.read_html(SITE)

# venueData2 = dfs[0]

# venueData2 = venueData2. 

# venueData2.to_csv('test.csv')
# Out:
# 15745

# %%
df_king = dfs[0].dropna()

# %%
# rename Pandas columns to lower case
df_king['url']= pd.NA
df_king.columns= df_king.columns.str.lower()

df_king = df_king.rename(
    columns = {"location name":"name","pm": "time"}
)
df_king = df_king[['name','url','state','day','time']]

def day_convert(st):
    try:
        return DAY_DICT[st]
    except KeyError:
        return st

df_king['time'] =  df_king['time'].astype(str)+'PM'
df_king['day'] = df_king['day'].apply(day_convert)

df_king
# Out:
# /var/folders/vw/8w1p1zwj0vb7_njj2l530q7w0000gn/T/ipykernel_88503/1013070126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_king['url']= pd.NA
#                        name   url state        day    time
# 1                 Madhatter  <NA>    DC     Monday  7:00PM
# 2            Tight Five Pub  <NA>    DC     Monday  7:00PM
# 3   Crystal City Sports Pub  <NA>    VA     Monday  8:00PM
# 5         Irish Channel Pub  <NA>    DC    Tuesday  7:00PM
# 7            Nanny O'Briens  <NA>    DC    Tuesday  7:30PM
# 8      Crafthouse Arlington  <NA>    VA    Tuesday  7:30PM
# 9        Crafthouse Fairfax  <NA>    VA    Tuesday  7:30PM
# 10        Crafthouse Reston  <NA>    VA    Tuesday  7:30PM
# 11         Samuel Beckett's  <NA>    VA    Tuesday  7:30PM
# 12                 Trusty's  <NA>    DC    Tuesday  8:00PM
# 13            New York Deli  <NA>    VA    Tuesday  8:00PM
# 16   World of Beer Richmond  <NA>    VA  Wednesday  7:30PM
# 17            Stoney's on P  <NA>    DC  Wednesday  8:00PM
# 18            P. J. Skidoos  <NA>    VA  Wednesday  8:00PM
# 20            Meridian Pint  <NA>    VA   Thursday  7:00PM
# 22  Brew Republic Bierwerks  <NA>    VA      Susp.  7:00PM
# 23    Union Jack's Columbia  <NA>    MD      Susp.  8:00PM

# %%
df = pd.concat([df_dist,df_king]).query("day==@DAYS")

# %%
def clean_name(nm):
    for day in DAYS:
        nm = nm.replace(f'({day})','')
        nm = nm.replace(f'({day}s)','')
    return (nm.replace('RVILL WED','Rockville').strip())


df['clean_name'] = df['name'].apply(clean_name)
df
# Out:
#                            name  \
# 0      Franklin Hall (Tuesdays)
# 1            Stadium Sports Bar
# 2           Capitol Cider House
# 3            The Eleanor (NoMa)
# 4               Across the Pond
# 5                  Crown & Crow
# 6               Astro Beer Hall
# 7                     Hook Hall
# 8                       Crimson
# 9             The Fainting Goat
# 10          Bonchon (Navy Yard)
# 11                  Penn Social
# 12                        TAP99
# 13                   Free State
# 14                The Big Stick
# 15    Irish Channel (Chinatown)
# 16      Franklin Hall (Mondays)
# 17                 Lost & Found
# 18                Roofers Union
# 19           The Board and Brew
# 20     Looney's Pub (Wednesday)
# 21           Caddies on Cordell
# 22  The Eleanor (Silver Spring)
# 23     True Respite Brewing Co.
# 24    World of Beer (RVILL WED)
# 25                 Highline RxR
# 26                 Auld Shebeen
# 27          Bar Bao (Thursdays)
# 28              Clare and Don's
# 29             Courthaus Social
# 30                  Blue Iguana
# 1                     Madhatter
# 2                Tight Five Pub
# 3       Crystal City Sports Pub
# 5             Irish Channel Pub
# 7                Nanny O'Briens
# 8          Crafthouse Arlington
# 9            Crafthouse Fairfax
# 10            Crafthouse Reston
# 11             Samuel Beckett's
# 12                     Trusty's
# 13                New York Deli
# 16       World of Beer Richmond
# 17                Stoney's on P
# 18                P. J. Skidoos
# 20                Meridian Pint
#
#                                                   url state        day  \
# 0                     https://www.franklinhalldc.com/    DC    Tuesday
# 1                    https://www.stadiumsportsdc.com/    DC  Wednesday
# 2                      https://capitolciderhouse.com/    DC   Thursday
# 3                          https://www.eleanordc.com/    DC     Sunday
# 4                    https://www.acrosstheponddc.com/    DC  Wednesday
# 5                     http://www.thecrownandcrow.com/    DC  Wednesday
# 6                       https://www.astrobeerhall.com    DC  Wednesday
# 7                           https://www.hookhall.com/    DC   Thursday
# 8                             https://crimson-dc.com/    DC    Tuesday
# 9                     https://www.faintinggoatdc.com/    DC  Wednesday
# 10  https://bonchon.com/korean-fried-chicken-navy-...    DC    Tuesday
# 11                           http://pennsocialdc.com/    DC    Tuesday
# 12                   https://www.facebook.com/tap99dc    DC     Monday
# 13                      https://www.freestatebar.com/    DC     Sunday
# 14                            http://thebigstick.com/    DC  Wednesday
# 15                     http://www.irishchanneldc.com/    DC  Wednesday
# 16                    https://www.franklinhalldc.com/    DC     Monday
# 17                     http://www.lostandfounddc.com/    DC     Monday
# 18                    http://roofersuniondc.com/#info    DC   Thursday
# 19                    http://www.theboardandbrew.com/    MD   Thursday
# 20      http://www.looneyspubmd.com/college_park.html    MD  Wednesday
# 21                   http://www.caddiesoncordell.com/    MD    Tuesday
# 22                         https://www.eleanormd.com/    MD     Sunday
# 23                           https://truerespite.com/    MD   Thursday
# 24        https://worldofbeer.com/Locations/Rockville    MD  Wednesday
# 25                            http://highlinerxr.com/    VA     Monday
# 26                      https://theauldshebeenva.com/    VA    Tuesday
# 27                 https://www.facebook.com/barbaova/    VA   Thursday
# 28                       http://www.clareanddons.com/    VA   Thursday
# 29  mailto:courthaussocial@gmail.com?Subject=Distr...    VA  Wednesday
# 30                      http://blueiguanafairfax.com/    VA   Thursday
# 1                                                <NA>    DC     Monday
# 2                                                <NA>    DC     Monday
# 3                                                <NA>    VA     Monday
# 5                                                <NA>    DC    Tuesday
# 7                                                <NA>    DC    Tuesday
# 8                                                <NA>    VA    Tuesday
# 9                                                <NA>    VA    Tuesday
# 10                                               <NA>    VA    Tuesday
# 11                                               <NA>    VA    Tuesday
# 12                                               <NA>    DC    Tuesday
# 13                                               <NA>    VA    Tuesday
# 16                                               <NA>    VA  Wednesday
# 17                                               <NA>    DC  Wednesday
# 18                                               <NA>    VA  Wednesday
# 20                                               <NA>    VA   Thursday
#
#       time                   clean_name
# 0   7:00PM                Franklin Hall
# 1   7:00PM           Stadium Sports Bar
# 2   7:00PM          Capitol Cider House
# 3   7:30PM           The Eleanor (NoMa)
# 4   7:30PM              Across the Pond
# 5   7:30PM                 Crown & Crow
# 6   7:00PM              Astro Beer Hall
# 7   7:00PM                    Hook Hall
# 8   7:00PM                      Crimson
# 9   7:00PM            The Fainting Goat
# 10  7:00PM          Bonchon (Navy Yard)
# 11  7:00PM                  Penn Social
# 12  7:00PM                        TAP99
# 13  7:00PM                   Free State
# 14  8:00PM                The Big Stick
# 15  7:00PM    Irish Channel (Chinatown)
# 16  7:00PM                Franklin Hall
# 17  8:00PM                 Lost & Found
# 18  7:30PM                Roofers Union
# 19  7:30PM           The Board and Brew
# 20  7:00PM                 Looney's Pub
# 21  7:30PM           Caddies on Cordell
# 22  7:30PM  The Eleanor (Silver Spring)
# 23  7:00PM     True Respite Brewing Co.
# 24  7:00PM    World of Beer (Rockville)
# 25  7:00PM                 Highline RxR
# 26  7:30PM                 Auld Shebeen
# 27  7:00PM                      Bar Bao
# 28  7:00PM              Clare and Don's
# 29  7:00PM             Courthaus Social
# 30  7:00PM                  Blue Iguana
# 1   7:00PM                    Madhatter
# 2   7:00PM               Tight Five Pub
# 3   8:00PM      Crystal City Sports Pub
# 5   7:00PM            Irish Channel Pub
# 7   7:30PM               Nanny O'Briens
# 8   7:30PM         Crafthouse Arlington
# 9   7:30PM           Crafthouse Fairfax
# 10  7:30PM            Crafthouse Reston
# 11  7:30PM             Samuel Beckett's
# 12  8:00PM                     Trusty's
# 13  8:00PM                New York Deli
# 16  7:30PM       World of Beer Richmond
# 17  8:00PM                Stoney's on P
# 18  8:00PM                P. J. Skidoos
# 20  7:00PM                Meridian Pint

# %%
home = [38.9191, -77.0363]


def get_place(name):
    params = {
        'input': name,
        'inputtype':'textquery',
        'fields':"%2C".join(['formatted_address','geometry']),
        'key':GOOGLE_MAPS_API_KEY,
        'locationbias':f'point:{home[0]},{home[1]}'
    }

    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'
    PLACES_URL = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'

    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key={GOOGLE_MAPS_API_KEY}"


    formatted_url = PLACES_URL + '?' + '&'.join(["{}={}".format(k,v) for k,v in params.items()])  # !
    # print(formatted_url)

    payload={}
    headers = {}

    # response = request("GET", url, headers=headers, data=payload)
    response = get(formatted_url,headers=headers, data=payload)
    # print(response.url)
    # print(response.text)
    return json.loads(response.text)


# venues = pd.read_csv('trivia_venues.csv',index_col=0)
# print(len(venues))

# for i in range(len(venues)):
#     params['address']=venues.loc[i,'Address']
#     req = requests.get(GOOGLE_MAPS_API_URL, params=params)
#     res = req.json()
#     result = res['results'][0]
#     lat = result['geometry']['location']['lat']
#     lng = result['geometry']['location']['lng']
#     venues.at[i,'lat']=lat
#     venues.at[i,'lng']=lng
#     print(i)
#     time.sleep(1) if i%50==0 else 1

# print(venues.loc[0:3,:])
# venues.to_csv('trivia_venues_loc.csv')

get_place(df['clean_name'][0])
# Out:
# {'candidates': [{'formatted_address': '1348 Florida Ave NW, Washington, DC 20009, United States',
#    'geometry': {'location': {'lat': 38.9200265, 'lng': -77.0312801},
#     'viewport': {'northeast': {'lat': 38.92145292989272,
#       'lng': -77.02997327010728},
#      'southwest': {'lat': 38.91875327010728, 'lng': -77.03267292989271}}}}],
#  'status': 'OK'}

# %%
place_data = [get_place(nm) for nm in df['clean_name']]

# %%
[place for place in place_data if len(place['candidates'])]
# Out:
# [{'candidates': [{'formatted_address': '8150 Baltimore Ave, College Park, MD 20740, United States',
#     'geometry': {'location': {'lat': 38.9908676, 'lng': -76.93432849999999},
#      'viewport': {'northeast': {'lat': 38.99231942989272,
#        'lng': -76.93305917010727},
#       'southwest': {'lat': 38.98961977010728, 'lng': -76.9357588298927}}}},
#    {'formatted_address': '8180 Maple Lawn Blvd, Fulton, MD 20759, United States',
#     'geometry': {'location': {'lat': 39.148425, 'lng': -76.906903},
#      'viewport': {'northeast': {'lat': 39.14969662989272,
#        'lng': -76.90566587010728},
#       'southwest': {'lat': 39.14699697010728, 'lng': -76.90836552989272}}}}],
#   'status': 'OK'}]

# %%
addresses = [dict(address=place['candidates'][0]['formatted_address'],
    lat=place['candidates'][0]['geometry']['location']['lat'],
    lng=place['candidates'][0]['geometry']['location']['lng']) for place in place_data]

# %%
df_addr = pd.DataFrame.from_records(addresses)
df_fin = pd.concat([df.reset_index(drop=True), df_addr], axis=1)

# %%
df_fin.query('day=="Wednesday"')
# Out:
#                          name  \
# 1          Stadium Sports Bar
# 4             Across the Pond
# 5                Crown & Crow
# 6             Astro Beer Hall
# 9           The Fainting Goat
# 14              The Big Stick
# 15  Irish Channel (Chinatown)
# 20   Looney's Pub (Wednesday)
# 24  World of Beer (RVILL WED)
# 29           Courthaus Social
# 42     World of Beer Richmond
# 43              Stoney's on P
# 44              P. J. Skidoos
#
#                                                   url state        day  \
# 1                    https://www.stadiumsportsdc.com/    DC  Wednesday
# 4                    https://www.acrosstheponddc.com/    DC  Wednesday
# 5                     http://www.thecrownandcrow.com/    DC  Wednesday
# 6                       https://www.astrobeerhall.com    DC  Wednesday
# 9                     https://www.faintinggoatdc.com/    DC  Wednesday
# 14                            http://thebigstick.com/    DC  Wednesday
# 15                     http://www.irishchanneldc.com/    DC  Wednesday
# 20      http://www.looneyspubmd.com/college_park.html    MD  Wednesday
# 24        https://worldofbeer.com/Locations/Rockville    MD  Wednesday
# 29  mailto:courthaussocial@gmail.com?Subject=Distr...    VA  Wednesday
# 42                                               <NA>    VA  Wednesday
# 43                                               <NA>    DC  Wednesday
# 44                                               <NA>    VA  Wednesday
#
#       time                 clean_name  \
# 1   7:00PM         Stadium Sports Bar
# 4   7:30PM            Across the Pond
# 5   7:30PM               Crown & Crow
# 6   7:00PM            Astro Beer Hall
# 9   7:00PM          The Fainting Goat
# 14  8:00PM              The Big Stick
# 15  7:00PM  Irish Channel (Chinatown)
# 20  7:00PM               Looney's Pub
# 24  7:00PM  World of Beer (Rockville)
# 29  7:00PM           Courthaus Social
# 42  7:30PM     World of Beer Richmond
# 43  8:00PM              Stoney's on P
# 44  8:00PM              P. J. Skidoos
#
#                                               address        lat        lng
# 1   300 Tingey St SE, Washington, DC 20003, United...  38.875173 -77.001475
# 4   1732 Connecticut Ave NW, Washington, DC 20009,...  38.913633 -77.046017
# 5   1317 14th St NW, Washington, DC 20005, United ...  38.907862 -77.031566
# 6   1306 G St NW, Washington, DC 20005, United States  38.898153 -77.030278
# 9   1330 U St NW, Washington, DC 20009, United States  38.916773 -77.030840
# 14    20 M St SE, Washington, DC 20003, United States  38.876657 -77.007631
# 15   500 H St NW, Washington, DC 20001, United States  38.899468 -77.019158
# 20  8150 Baltimore Ave, College Park, MD 20740, Un...  38.990868 -76.934328
# 24  196 E Montgomery Ave #B, Rockville, MD 20850, ...  39.084257 -77.150331
# 29  2300 Clarendon Blvd, Arlington, VA 22201, Unit...  38.890194 -77.086535
# 42  11600 W Broad St, Richmond, VA 23233, United S...  37.652172 -77.613216
# 43  1433 P St NW, Washington, DC 20005, United States  38.909824 -77.033288
# 44  9908 Fairfax Blvd, Fairfax, VA 22030, United S...  38.863722 -77.287168

# %%
df_fin.to_csv('trivia_venues_loc.csv')
